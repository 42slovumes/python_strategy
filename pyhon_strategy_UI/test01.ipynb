# %%
from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager

api_key = 'Hbl4LB7f4I1ksA4wsIoZWSY5DIwaks7wkaa2JAXDyjSzHbJpSrao6ypMWj4ukRmE'
api_secret = '5B9eEOR4ewonBjGJ1oL8Qui70KRI9q5ezcfUdGfXBctvrOKfYNi0tzqLSCRdaP4V'

client = Client(api_key, api_secret)

# %%
depth = client.get_order_book(symbol='BNBBTC')
account = client.get_account()
balances = account['balances']
for balance in balances:
    print(balance)

# %%
klines = client.get_klines(symbol='BTCUSDT', interval=Client.KLINE_INTERVAL_1MINUTE)

for kline in klines:
    print(kline)
# Out:
# [1678924380000, '24287.73000000', '24321.15000000', '24275.42000000', '24276.52000000', '262.34468000', 1678924439999, '6374585.44293580', 6746, '138.84140000', '3373784.46062440', '0']
# [1678924440000, '24275.42000000', '24278.49000000', '24244.68000000', '24266.85000000', '231.37956000', 1678924499999, '5612612.23858620', 7206, '122.94408000', '2982361.14460820', '0']
# [1678924500000, '24269.00000000', '24288.44000000', '24261.50000000', '24275.00000000', '159.57111000', 1678924559999, '3873555.66236580', 5288, '83.81023000', '2034523.78842000', '0']
# [1678924560000, '24273.54000000', '24280.73000000', '24247.00000000', '24248.86000000', '192.23716000', 1678924619999, '4664074.76608040', 5903, '92.05775000', '2233547.04720090', '0']
# [1678924620000, '24248.86000000', '24283.65000000', '24223.00000000', '24278.03000000', '387.80029000', 1678924679999, '9406880.83546220', 9476, '217.69029000', '5280554.87501520', '0']
# ...
